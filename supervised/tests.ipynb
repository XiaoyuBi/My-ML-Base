# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### sklearn

# %%
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)
diabetes_y = diabetes_y[:, np.newaxis]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X, diabetes_y)

# Make predictions
diabetes_y_pred = regr.predict(diabetes_X)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y, diabetes_y_pred))
# Out:
# Coefficients:
#  [[ -10.0098663  -239.81564367  519.84592005  324.3846455  -792.17563855
#    476.73902101  101.04326794  177.06323767  751.27369956   67.62669218]]
# Mean squared error: 2859.70

# %% [markdown]
# ### My Linear Regression

# %%
from linear_regression import LinearRegression

myLinearRegression = LinearRegression(lr = 0.1, n_iter = 100)
myLinearRegression.train(diabetes_X, diabetes_y)

# Make predictions
diabetes_y_pred = myLinearRegression.forward(diabetes_X)

# The coefficients
print("Coefficients: (with intercept) \n", myLinearRegression.linear.W.T)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y, diabetes_y_pred))
# Out:
# Coefficients: (with intercept)
#  [[152.13348413  12.33197469   2.07841523  40.5153368   30.14245223
#    13.30468394  10.6377592  -26.88006287  28.38626698  38.52275316
#    25.59714177]]
# Mean squared error: 5261.11

# %%
myLinearRegression = LinearRegression(lr = 0.1, momentum = 0.9, n_iter = 100)
myLinearRegression.train(diabetes_X, diabetes_y)

# Make predictions
diabetes_y_pred = myLinearRegression.forward(diabetes_X)

# The coefficients
print("Coefficients: (with intercept) \n", myLinearRegression.linear.W.T)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y, diabetes_y_pred))
# Out:
# Coefficients: (with intercept)
#  [[ 152.56789014   52.7118622   -25.12911059  256.77346731  181.43265325
#     43.29402579   19.43679489 -150.88014018  140.41618384  230.23675131
#    133.47150188]]
# Mean squared error: 3416.17
